# %%
######## PREGUNTA 4 EXAMEN ########
p = 0x01ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
n = 0x01fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffa51868783bf2f966b7fcc0148f709a5d03bb5c9b8899c47aebb6fb71e91386409
a = 0x01fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffc
b =  0x0051953eb9618e1c9a1f929a21a0b68540eea2da725b99b315f3b8b489918ef109e156193951ec7e937b1652c0bd3bb1bf073573df883d2c34f1ef451fd46b503f00
Gx = 0x6b17d1f2e12c4247f8bce6e563a440f277037d812deb33a0f4a13945d898c296
Gy = 0x4fe342e2fe1a7f9b8ee7eb4a7c0f9e162bce33576b315ececbb6406837bf51f5

# valores extraidos del campo subjectPublicKy con Wireshark
Qx = 183746701883757124826755524715142517173684662596382931014900106779410231692051781676595944589173697763631191386590655544007103631661168945042439908049126628
Qy = 183746701883757124826755524715142517173684662596382931014900106779410231692051781676595944589173697763631191386590655544007103631661168945042439908049126628
# valores extraidos del campo signature con Wireshark
F1=636209411702914270661152765691119681822202526214190888223313780804486620649417809538075073320536552396577393606651565148805816715408423177786550261549407061
F2=5665944802029951168612385975560511149978964867796618009229554554695039618868560857058585498994051253971070241725582009074416192241470619741064412300461145432
# 256 bits producto de la concatenación de los binarios
result = 5572218363369325710622755349080158642966138912594496268137619782031501993116570169733490485653610033368823165157382759353621377017869899053722083617134315051


EC = EllipticCurve(Zmod(p),[a,b])
if EC.cardinality().is_prime():
    print("El orden es primo")

Q = EC([Qx,Qy])
# Q.order()

# Verificación firma 
Punto = EC([Gx,Gy])
k = mod(result*F2^-1,n)
l = mod(F1*F2^-1,n)
verify = Integer(k)*Punto+Q*Integer(l)
if mod(verify[0],n) == F1:
    print("Firma válida")
else:
    print("Firma no válida")

# %%
######## PREGUNTA 11 EXAMEN ########

p = 0xfffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffeffffffff0000000000000000ffffffff
orden = 0xffffffffffffffffffffffffffffffffffffffffffffffffc7634d81f4372ddf581a0db248b0a77aecec196accc52973
a=0xfffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffeffffffff0000000000000000fffffffc
b = 0xb3312fa7e23ee7e4988e056be3f82d19181d9c6efe8141120314088f5013875ac656398d8a2ed19d2a85c8edd3ec2aef
Gx=0xaa87ca22be8b05378eb1c71ef320ad746e1d3b628ba79b9859f741e082542a385502f25dbf55296c3a545e3872760ab7 
Gy=0x3617de4a96262c6f5d9e98bf9292dc29f8f41dbd289a147ce9da3113b5f0b8c00a60b1ce1d7e819d7a431d7c90ea0e5f
#Defino la curva
Zp= Zmod(p)
E = EllipticCurve(Zp,[a,b]);
# Defino el generador
G = E([Gx,Gy])

show(html('Curva P-256'))
show(html('$y^2=x^3-3\\,x + b\\mod p$'))
show(html('$p=2^{256} − 2^{224} + 2^{192} + 2^{96} − 1=$'+'${}$'.format(p)))
show(html('$b={}$'.format(b)))
show(html('Generador $G={}$'.format(G)))

print('Es el orden primo?',is_prime(orden))
print('El generador es de la curva? ', mod(Gy**2,p)==mod(Gx**3+a*Gx+b,p))


a=0x8708878e50041df55aeaf58e1ee03dc723aab45d36d47f4e1d49597b35aa6eb2f29b815b3131a4d8225610e909c4ca2f
b=0x47147e25d90562e96e978cff70ff1c208a482c28ebcc45d3552d62d4eb65c45ed0a7ed1b1c8f998ad9a7240e9bf12e9

alpha=a*G
beta=b*G
show(html('Alicia envía $\\alpha={}$'.format(alpha)))
show(html('Benito envía $\\beta={}$'.format(beta)))

delta_a=a*beta
delta_b=b*alpha

print('Han llegado al mismo secreto?',delta_a==delta_b)
print(delta_a)

# %%
########## PREGUNTA 2 EXAMEN ##########
NdeBitsDelModulo=2048*2
limite=2^(NdeBitsDelModulo/2);

n1=11704458880696591489703356592616416025127868098410953766007322413765303922671395383720842616703077269781776882240487;

n2=17234261282515109030920373387929821699941371306961933980268800658182839692020822375533773555017682851968911081539163;

n3=19053471012090780990243272591945771901765983282293268088579846661520394095256752218097009967231753236434269475701791;

n4=22610770261657789496058163182213778222550168328189289540160032215867782655240728693716233181590330679713873208985719;

n5=21950753793319115751513988943054963225104568326742396944258659289484943230064914465252162060935004886578442146573447;


e=5;


c1=2381135004837897289190972124556231417118807930731324069160257956664435609464314385680469250470620831138095008900646;
c2=2499873093349932324023281425895296431137480523032368295855507740581860865528598028799191990665092208197509522428214;
c3=3632473745988792738802194052469335467505548049564875725126918423915403348043645271089535418777120141385580888901037;
c4=1409220620617001057501573888283159677104961770966421376214595069656842417134099099261984297868300102501573653994925;
c5=12270886775846611899442389328947778782582612652536625498026593376049816567444568574813082551421753150567283738309639;
#---------------------
#Empieza ataque
#---------------------
print("\n---------------- Empiezo los cálculos para descifrar------------------")
t0=cputime()
s = s = (crt(crt(crt(crt(c1, c2, n1, n2), c3, n1 * n2, n3), c4, n1 * n2 * n3, n4), c5, n1 * n2 * n3 * n4, n5))^(1 / e)
#s=(crt(crt(c1,c2,n1,n2),c3,n1*n2,n3))^(1/e);
t1=cputime()

print("\nmensaje recuperado=",s);

print("\n Tiempo=",t1-t0)

# %%
###########  PREGUNTA 7 EXAMEN ANTERIOR ###########

NdeBitsDelModulo=2048;
limite=2^(NdeBitsDelModulo/2);

n=;
e1=631;
e2=419;



m=mod(randint(0,limite),n);
c1=;
c2=;

#---------------------
#Empieza ataque
#---------------------
t0=cputime()
bezout=xgcd(e1,e2)
print(bezout)
m_rec=mod(mod(c1^bezout[1],n)*mod(c2^bezout[2],n),n)
t1=cputime()

print("mensaje original=",m);
print("mensaje recuperado=",m_rec);
print("\n Tiempo=",t1-t0)
